# %% [markdown]
# CCTV 공공데이터

# %%
# CCTV 정보 사용하여 지도 표출
import folium
import pandas as pd

cctv_ndf = pd.read_csv('/content/세종특별자치시_CCTV_20210101.csv')

cctv_nr = cctv_ndf.loc[:,['카메라화소수','위도','경도']]

cctv_map = folium.Map(location=[cctv_route['위도'].mean(),cctv_route['경도'].mean()],
                 zoom_start=11)

for n in cctv_nr.index:
  folium.Marker([cctv_nr.loc[n, '위도'], 
                 cctv_nr.loc[n, '경도']],
                icon=folium.Icon(icon='video-camera', prefix='fa')).add_to(cctv_map)
cctv_map
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f346abd7cac5> in <module>()
#       7 cctv_nr = cctv_ndf.loc[:,['카메라화소수','위도','경도']]
#       8
# ----> 9 cctv_map = folium.Map(location=[cctv_route['위도'].mean(),cctv_route['경도'].mean()],
#      10                  zoom_start=11)
#      11
#
# NameError: name 'cctv_route' is not defined

# %%
cctv_ndf.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a6e9f072ba15> in <module>()
# ----> 1 cctv_ndf.info()
#
# NameError: name 'cctv_ndf' is not defined
