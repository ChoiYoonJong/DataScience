# %% [markdown]
# 자전거 대여소 공공데이터 준비하기

# %%
# 1. Pandas 선언
import pandas as pd

# 2. CSV 파일 불러오기
df = pd.read_csv('/content/세종특별자치시_공영자전거 어울링 대여소_20200915.csv',encoding='cp949')
df.head()
# Out:
#    STATION_ID STATION_NM  AREA  GU  ... ADDR2 LOCKER      Y_POS       X_POS
# 0           1    첫마을 1단지  1생활권  세종  ...   NaN     13  36.482114  127.259628
# 1           2    첫마을 3단지  1생활권  세종  ...   NaN     15  36.479850  127.260513
# 2           3   첫마을  4단지  1생활권  세종  ...   NaN     15  36.480436  127.253314
# 3           4   LH세종특별본부  2생활권  세종  ...   NaN     15  36.495484  127.266063
# 4           5   한솔동 주민센터  1생활권  세종  ...   NaN     14  36.478979  127.255524
#
# [5 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   STATION_ID  72 non-null     int64
#  1   STATION_NM  72 non-null     object
#  2   AREA        72 non-null     object
#  3   GU          72 non-null     object
#  4   DONG        72 non-null     object
#  5   ADDR1       72 non-null     object
#  6   ADDR2       0 non-null      float64
#  7   LOCKER      72 non-null     int64
#  8   Y_POS       72 non-null     float64
#  9   X_POS       72 non-null     float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 5.8+ KB

# %% [markdown]
# 지도에 표시할 대여소 정보 추출

# %%
df_route = df.loc[:,['STATION_NM','AREA','Y_POS','X_POS']]
df_route.head()
# Out:
#   STATION_NM  AREA      Y_POS       X_POS
# 0    첫마을 1단지  1생활권  36.482114  127.259628
# 1    첫마을 3단지  1생활권  36.479850  127.260513
# 2   첫마을  4단지  1생활권  36.480436  127.253314
# 3   LH세종특별본부  2생활권  36.495484  127.266063
# 4   한솔동 주민센터  1생활권  36.478979  127.255524

# %% [markdown]
# 자전거 대여소 Marker 활용하여 지도 표출

# %%
# 지도에 표시하기 위해 folium 라이브러리
import folium

map = folium.Map(location=[df_route['Y_POS'].mean(),df_route['X_POS'].mean()],
                 zoom_start=11)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_28d61080b9ff42a2b3e133038863e787%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_28d61080b9ff42a2b3e133038863e787%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_28d61080b9ff42a2b3e133038863e787%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_28d61080b9ff42a2b3e133038863e787%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_19f1bd412e8f4d17bd6fb8475965010f%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %%
# 지도에 표시하기 위해 folium 라이브러리
import folium

map = folium.Map(location=[df_route['Y_POS'].mean(),df_route['X_POS'].mean()],
                 zoom_start=11)

for n in df_route.index:

  if df_route.loc[n, 'AREA'] == '1생활권':
    folium.Marker([df_route.loc[n, 'Y_POS'],df_route.loc[n, 'X_POS']], # 위도 , 경도
                popup=df_route.loc[n, 'STATION_NM']+''+ df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='darkred', icon='fa-bicycle', prefix='fa')).add_to(map)
 
  elif df_route.loc[n, 'AREA'] == '2생활권':
    folium.Marker([df_route.loc[n, 'Y_POS'],df_route.loc[n, 'X_POS']], # 위도 , 경도
                popup=df_route.loc[n, 'STATION_NM']+''+ df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='blue', icon='fa-bicycle', prefix='fa')).add_to(map)
  
  elif df_route.loc[n, 'AREA'] == '3생활권':
    folium.Marker([df_route.loc[n, 'Y_POS'],df_route.loc[n, 'X_POS']], # 위도 , 경도
                popup=df_route.loc[n, 'STATION_NM']+''+ df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='red', icon='fa-bicycle', prefix='fa')).add_to(map)

  elif df_route.loc[n, 'AREA'] == '4생활권':
    folium.Marker([df_route.loc[n, 'Y_POS'],df_route.loc[n, 'X_POS']], # 위도 , 경도
                popup=df_route.loc[n, 'STATION_NM']+''+ df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='black', icon='fa-bicycle', prefix='fa')).add_to(map)

  else:
    folium.Marker([df_route.loc[n, 'Y_POS'],df_route.loc[n, 'X_POS']], # 위도 , 경도
                popup=df_route.loc[n, 'STATION_NM']+''+ df_route.loc[n, 'AREA'],
                icon=folium.Icon(color='green', icon='fa-bicycle', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_6811ad54bdfe493c9103fbcdfc4697d6%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6811ad54bdfe493c9103fbcdfc4697d6%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_6811ad54bdfe493c9103fbcdfc4697d6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_6811ad54bdfe493c9103fbcdfc4697d6%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_f348ed43a3304c01ab19fb7e2eac216f%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %%
# 지도에 표시하기 위해 folium 라이브러리
import folium
map = folium.Map(location=[df_route['Y_POS'].mean(), df_route['X_POS'].mean()],
                           zoom_start = 11)

c = ['green','blue','red','gray']

for n in df_route.index:
    for i in range(0,4):
        if df_route.loc[n, 'AREA'][0] == str(i+1):
            folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
            popup = df_route.loc[n, 'STATION_NM'] + ' ' + df_route.loc[n, 'AREA'],
            icon=folium.Icon(color=c[i], icon='fa-bicycle', prefix='fa')).add_to(map)
            break  
        else:
            folium.Marker([df_route.loc[n, 'Y_POS'], df_route.loc[n, 'X_POS']], # 위도, 경도
            popup = df_route.loc[n, 'STATION_NM'] + ' ' + df_route.loc[n, 'AREA'],
            icon=folium.Icon(color='orange', icon='fa-bicycle', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1cc87ac2a4594af6a78ccedfbfdf36d8%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1cc87ac2a4594af6a78ccedfbfdf36d8%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1cc87ac2a4594af6a78ccedfbfdf36d8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1cc87ac2a4594af6a78ccedfbfdf36d8%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_6a3196301f7b4bd4ab6cc2dccf471388%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# 가로등 설치 공공데이터 준비하기

# %%
lamp_df = pd.read_csv('/content/세종특별자치시_가로등정보_20190919.csv',encoding='cp949')
lamp_df.head()
# Out:
#               가로등위치명  설치대수 소재지도로명주소  ...      관리기관전화번호     관리기관명     데이터기준일자
# 0      전동면 노장리 609-9     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 1  세종특별자치시 대평동 574-2     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 2      전동면 노장리 609-9     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 3  세종특별자치시 대평동 574-2     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
# 4      연기면 산울리 141-3     1      NaN  ...  044-300-5132  세종특별자치시청  2019-09-19
#
# [5 rows x 11 columns]

# %% [markdown]
# 지도에 표시할 가로등 정보 추출

# %%
lamp_route = lamp_df.loc[:,['가로등위치명','위도','경도']]
lamp_route.head()
# Out:
#               가로등위치명         위도          경도
# 0      전동면 노장리 609-9  36.652672  127.268525
# 1  세종특별자치시 대평동 574-2  36.469947  127.269149
# 2      전동면 노장리 609-9  36.654752  127.268148
# 3  세종특별자치시 대평동 574-2  36.469487  127.268955
# 4      연기면 산울리 141-3  36.529309  127.264695

# %% [markdown]
# 가로등 Marker 활용하여 지도 표출

# %%
lamp_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15460 entries, 0 to 15459
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가로등위치명  15460 non-null  object
#  1   위도      15460 non-null  float64
#  2   경도      15460 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 362.5+ KB

# %%
# 가로등 정도 100건만 사용하여 지도 표출

for n in lamp_route.index[:100]:
  folium.Marker([lamp_route.loc[n, '위도'], lamp_route.loc[n, '경도']], # 위도, 경도
            popup = lamp_route.loc[n, '가로등위치명'],
            icon=folium.Icon(icon='lightbulb-o', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1cc87ac2a4594af6a78ccedfbfdf36d8%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1cc87ac2a4594af6a78ccedfbfdf36d8%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1cc87ac2a4594af6a78ccedfbfdf36d8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1cc87ac2a4594af6a78ccedfbfdf36d8%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_6a3196301f7b4bd4ab6cc2dccf471388%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...

# %% [markdown]
# CCTV 공공데이터

# %%
cctv_df = pd.read_csv('/content/세종특별자치시_CCTV_20210101.csv',encoding='cp949')
cctv_df.head()
# Out:
#      관리기관명             소재지도로명주소  ...          경도     데이터기준일자
# 0  세종특별자치시  세종특별자치시 조치원읍 건강길 16  ...  127.296286  2021-01-01
# 1  세종특별자치시                  NaN  ...  127.302452  2021-01-01
# 2  세종특별자치시                  NaN  ...  127.300492  2021-01-01
# 3  세종특별자치시                  NaN  ...  127.301301  2021-01-01
# 4  세종특별자치시                  NaN  ...  127.303145  2021-01-01
#
# [5 rows x 12 columns]

# %%
cctv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   관리기관명     1234 non-null   object
#  1   소재지도로명주소  413 non-null    object
#  2   소재지지번주소   1097 non-null   object
#  3   설치목적구분    1234 non-null   object
#  4   카메라대수     1234 non-null   int64
#  5   카메라화소수    1234 non-null   object
#  6   촬영방면정보    1234 non-null   object
#  7   보관일수      1234 non-null   int64
#  8   관리기관전화번호  1234 non-null   object
#  9   위도        1232 non-null   float64
#  10  경도        1232 non-null   float64
#  11  데이터기준일자   1234 non-null   object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 115.8+ KB

# %% [markdown]
# 지도에 표시할 CCTV 정보 추출

# %%
cctv_route = cctv_df.loc[:,['카메라화소수','위도','경도']]
cctv_route.head()
# Out:
#             카메라화소수         위도          경도
# 0      200,200,200  36.605059  127.296286
# 1          200,200  36.597678  127.302452
# 2      200,200,200  36.594863  127.300492
# 3      200,200,200  36.600620  127.301301
# 4  130,200,200,200  36.602434  127.303145

# %%
cctv_route.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1234 entries, 0 to 1233
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   카메라화소수  1234 non-null   object
#  1   위도      1232 non-null   float64
#  2   경도      1232 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 29.0+ KB

# %%
# CCTV 정도 100건만 사용하여 지도 표출

for n in cctv_route.index[:100]:
  folium.Marker([cctv_route.loc[n, '위도'], cctv_route.loc[n, '경도']], # 위도, 경도
            popup = cctv_route.loc[n, '카메라화소수'],
            icon=folium.Icon(icon='video-camera', prefix='fa')).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_1cc87ac2a4594af6a78ccedfbfdf36d8%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_1cc87ac2a4594af6a78ccedfbfdf36d8%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_1cc87ac2a4594af6a78ccedfbfdf36d8%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_1cc87ac2a4594af6a78ccedfbfdf36d8%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B36.51046252638888%2C%20127.26477946527774%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_6a3196301f7b4bd4ab6cc2dccf471388%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0 ...
